# %%
import pandas as pd

# %%
df = pd.read_csv("pokemon_data.csv")

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.head(7)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
# 5  5             Charmeleon   Fire     NaN  58      64       58       80
# 6  6              Charizard   Fire  Flying  78      84       78      109
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.iloc[2:8]
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
#
#    Sp. Def  Speed  Generation  Legendary
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df[['Name', 'HP', 'Defense']].head()
# Out:
#                     Name  HP  Defense
# 0              Bulbasaur  45       49
# 1                Ivysaur  60       63
# 2               Venusaur  80       83
# 3  VenusaurMega Venusaur  80      123
# 4             Charmander  39       43

# %%
my_df = df[df['Name'] == 'Diancie']

# %%
my_df
# Out:
#        #     Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 795  719  Diancie   Rock  Fairy  50     100      150      100      150     50
#
#      Generation  Legendary
# 795           6       True

# %%
df.index
# Out:
# RangeIndex(start=0, stop=800, step=1)

# %%
my_df.index
# Out:
# Int64Index([795], dtype='int64')

# %%
my_df.head()
# Out:
#        #     Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 795  719  Diancie   Rock  Fairy  50     100      150      100      150     50
#
#      Generation  Legendary
# 795           6       True

# %%
df.set_index('Defense')
# Out:
#            #                   Name   Type 1  Type 2  HP  Attack  Sp. Atk  \
# Defense
# 49         1              Bulbasaur    Grass  Poison  45      49       65
# 63         2                Ivysaur    Grass  Poison  60      62       80
# 83         3               Venusaur    Grass  Poison  80      82      100
# 123        3  VenusaurMega Venusaur    Grass  Poison  80     100      122
# 43         4             Charmander     Fire     NaN  39      52       60
# ...      ...                    ...      ...     ...  ..     ...      ...
# 150      719                Diancie     Rock   Fairy  50     100      100
# 110      719    DiancieMega Diancie     Rock   Fairy  50     160      160
# 60       720    HoopaHoopa Confined  Psychic   Ghost  80     110      150
# 60       720     HoopaHoopa Unbound  Psychic    Dark  80     160      170
# 120      721              Volcanion     Fire   Water  80     110      130
#
#          Sp. Def  Speed  Generation  Legendary
# Defense
# ...

# %%
df["Defense"].plot()
# Out:
# <AxesSubplot:>

# %%
order = [1, 2, 3, 4, 5,'r']
series = [10, 20, 30, 40, 5,600]

# %%
series_s = pd.Series(series, index = order)
series_s
# Out:
# 1     10
# 2     20
# 3     30
# 4     40
# 5      5
# r    600
# dtype: int64

# %%
data = { 
       'ID': [1, 2, 3, 4, 5, 6],
       'Name': ['Usman', 'Ali', 'Umer', 'Ayyan', 'Haris', 'Tayyab'],
       'Department' : ['CS', 'CS', 'SE', 'EE', 'CS', 'EE'],
       'Roll-Number': ['19P-0068', '19P-0100', '19P-0230', '19P-1000', '19P-0001', '19P-0002']
       }

# %%
std = pd.DataFrame(data, columns = ['ID', 'Name', 'Roll-Number', 'Department'])

# %%
std
# Out:
#    ID    Name Roll-Number Department
# 0   1   Usman    19P-0068         CS
# 1   2     Ali    19P-0100         CS
# 2   3    Umer    19P-0230         SE
# 3   4   Ayyan    19P-1000         EE
# 4   5   Haris    19P-0001         CS
# 5   6  Tayyab    19P-0002         EE

# %%
a = pd.Series([1,2,4,5,6])
b = pd.Series([34,5,5,6,1])

# %%
pd.DataFrame({'a':a, 'b':b})
# Out:
#    a   b
# 0  1  34
# 1  2   5
# 2  4   5
# 3  5   6
# 4  6   1

# %%
df = pd.read_csv("pokemon_data.csv")

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.iloc[2: 14]
# Out:
#      #                       Name Type 1  Type 2  HP  Attack  Defense  \
# 2    3                   Venusaur  Grass  Poison  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison  80     100      123
# 4    4                 Charmander   Fire     NaN  39      52       43
# 5    5                 Charmeleon   Fire     NaN  58      64       58
# 6    6                  Charizard   Fire  Flying  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying  78     104       78
# 9    7                   Squirtle  Water     NaN  44      48       65
# 10   8                  Wartortle  Water     NaN  59      63       80
# 11   9                  Blastoise  Water     NaN  79      83      100
# 12   9    BlastoiseMega Blastoise  Water     NaN  79     103      120
# 13  10                   Caterpie    Bug     NaN  45      30       35
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.set_index('Name')
# Out:
#                          #   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur                1    Grass  Poison  45      49       49       65
# Ivysaur                  2    Grass  Poison  60      62       63       80
# Venusaur                 3    Grass  Poison  80      82       83      100
# VenusaurMega Venusaur    3    Grass  Poison  80     100      123      122
# Charmander               4     Fire     NaN  39      52       43       60
# ...                    ...      ...     ...  ..     ...      ...      ...
# Diancie                719     Rock   Fairy  50     100      150      100
# DiancieMega Diancie    719     Rock   Fairy  50     160      110      160
# HoopaHoopa Confined    720  Psychic   Ghost  80     110       60      150
# HoopaHoopa Unbound     720  Psychic    Dark  80     160       60      170
# Volcanion              721     Fire   Water  80     110      120      130
#
#                        Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
df_sort = df.sort_values(['Type 1', 'Attack'], ascending = [1, 1])

# %%
df_sort.head()
# Out:
#        #     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  213  Shuckle    Bug    Rock  20      10      230       10      230
# 14    11  Metapod    Bug     NaN  50      20       55       25       25
# 179  165   Ledyba    Bug  Flying  40      20       30       40       80
# 733  665   Spewpa    Bug     NaN  45      22       60       27       30
# 17    14   Kakuna    Bug  Poison  45      25       50       25       25
#
#      Speed  Generation  Legendary
# 230      5           2      False
# 14      30           1      False
# 179     55           2      False
# 733     29           6      False
# 17      35           1      False
